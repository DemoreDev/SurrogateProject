# %% [markdown]
# # Análise e Construção do Pipeline de Pré-processamento
#
# ## Objetivos Principais
# ### Este notebook serve como o ambiente central para o desenvolvimento e validação da etapa de processamento dos dados. Seus objetivos são:
#
# * #### **1. Explorar e Prototipar:** Carregar os dados brutos, analisar sua estrutura e testar diferentes lógicas de limpeza e transformação.
# * #### **2. Validar o Processo:** Executar cada etapa de forma isolada para garantir que o resultado seja o esperado antes de automatizar o fluxo.
# * #### **3. Documentar as Decisões:** Servir como uma "documentação viva" que explica o *porquê* de cada etapa de pré-processamento.
# * #### **4. Refatorar para Reutilização:** Consolidar a lógica validada em funções Python modulares, que serão movidas para a pasta `/src` para serem facilmente importadas e reutilizadas no pipeline de modelagem.

# %% [markdown]
# ### Biliotecas utilizadas:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ### Leitura dos dados brutos

# %%
# Para ver o comportamento das variáveis
path = Path('../data/raw/birds.csv') 
df = pd.read_csv(path, sep=';')
df
# Out:
#         normalize  NO_FEATURE_PREPROCESSING  mlfs.igmf_adapted.PyIT_IGMF  \
# 0               0                       NaN                          NaN
# 1               0                       NaN                          NaN
# 2               0                       NaN                          NaN
# 3               0                       NaN                          NaN
# 4               0                       NaN                          NaN
# ...           ...                       ...                          ...
# 135910          1                       NaN                          NaN
# 135911          1                       NaN                          NaN
# 135912          1                       NaN                          NaN
# 135913          1                       NaN                          NaN
# 135914          1                       NaN                          NaN
#
#         mlfs.igmf_adapted.PyIT_IGMF-n_features  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 135910                                     NaN
# 135911                                     NaN
# 135912                                     NaN
# 135913                                     NaN
# 135914                                     NaN
#
#         mlfs.ppt_mi_adapted.PyIT_PPT_MI  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 135910                              NaN
# 135911                              NaN
# 135912                              NaN
# 135913                              NaN
# 135914                              NaN
#
#         mlfs.ppt_mi_adapted.PyIT_PPT_MI-n_features  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 135910                                         NaN
# 135911                                         NaN
# 135912                                         NaN
# 135913                                         NaN
# 135914                                         NaN
#
#         mlfs.scls_adapted.PyIT_SCLS  mlfs.scls_adapted.PyIT_SCLS-n_features  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
# ...                             ...                                     ...
# 135910                          NaN                                     NaN
# 135911                          NaN                                     NaN
# 135912                          NaN                                     NaN
# 135913                          NaN                                     NaN
# 135914                          NaN                                     NaN
#
#         mlfs.lrfs_adapted.PyIT_LRFS  mlfs.lrfs_adapted.PyIT_LRFS-n_features  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
# ...                             ...                                     ...
# 135910                          NaN                                     NaN
# 135911                          NaN                                     NaN
# 135912                          NaN                                     NaN
# 135913                          NaN                                     NaN
# 135914                          NaN                                     NaN
#
#         ...  weka.classifiers.functions.supportVector.NormalizedPolyKernel  \
# 0       ...                                                NaN
# 1       ...                                                NaN
# 2       ...                                                NaN
# 3       ...                                                NaN
# 4       ...                                                NaN
# ...     ...                                                ...
# 135910  ...                                                NaN
# 135911  ...                                                NaN
# 135912  ...                                                NaN
# 135913  ...                                                NaN
# 135914  ...                                                NaN
#
#         weka.classifiers.functions.supportVector.NormalizedPolyKernel-E  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 135910                                                NaN
# 135911                                                NaN
# 135912                                                NaN
# 135913                                                NaN
# 135914                                                NaN
#
#         weka.classifiers.functions.supportVector.NormalizedPolyKernel-L  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 135910                                                NaN
# 135911                                                NaN
# 135912                                                NaN
# 135913                                                NaN
# 135914                                                NaN
#
#         weka.classifiers.functions.supportVector.Puk  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 135910                                           NaN
# 135911                                           NaN
# 135912                                           NaN
# 135913                                           NaN
# 135914                                           NaN
#
#         weka.classifiers.functions.supportVector.Puk-O  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 135910                                             NaN
# 135911                                             NaN
# 135912                                             NaN
# 135913                                             NaN
# 135914                                             NaN
#
#         weka.classifiers.functions.supportVector.Puk-S  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 135910                                             NaN
# 135911                                             NaN
# 135912                                             NaN
# 135913                                             NaN
# 135914                                             NaN
#
#         weka.classifiers.functions.supportVector.RBFKernel  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 135910                                                NaN
# 135911                                                NaN
# 135912                                                NaN
# 135913                                                NaN
# 135914                                                NaN
#
#         weka.classifiers.functions.supportVector.RBFKernel-G  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 135910                                                NaN
# 135911                                                NaN
# 135912                                                NaN
# 135913                                                NaN
# 135914                                                NaN
#
#         F1 (macro averaged by label)  Model Size
# 0                              0.256     37076.0
# 1                              0.222     29686.0
# 2                              0.026     18387.0
# 3                              0.543   6177677.0
# 4                              0.171     28237.0
# ...                              ...         ...
# 135910                         0.077   1172364.0
# 135911                           NaN         NaN
# 135912                         0.169    232446.0
# 135913                         0.290    486521.0
# 135914                         0.119    345333.0
#
# [135915 rows x 209 columns]

# %% [markdown]
# #### Notas
# - A primeira coluna se refere a 'normalização', e seus valores podem assumir 0 (caso NÃO tenha normalização aplicada) ou 1 (caso TENHA normalização aplicada).
#
# - A segunda coluna se refere à etapa de 'feature preprocessing'. Caso tenha ocorrido, a célula tem o valor NaN; caso NÃO tenha ocorrido, a célula fica como 0.
#
# - Há muitas colunas NaN. Cada NaN representa 'não se aplica', por exemplo, caso um algoritmo não tenha sido usado naquela execução, sua célula será NaN e seus hiperparâmetros também.
#
# - Caso um algoritmo tenha sido usado naquela execução, sua célula será 0.0 (indicando 'se aplica') e seus hiperparâmetros serão os valores reais que foram usados naquela execução.
#
# Os padrões acima se repetem durante todo o dataset, exceto para as duas últimas colunas (F1-score e Model Size, respectivamente)
#
# - As duas últimas colunas (F1-score e Model Size) assumem os valores reais da execução (ou NaN caso não tenham sido calculadas). Ou seja, algumas execuções possuem ambos os valores "target" e algumas não possuem nenhum dos dois.
#
# - Existem features (colunas) categóricas, como as dos algoritmos, que indicam apenas sim ou não para a presença de determinado algoritmo. Também existem features (colunas) numéricas, como aquelas de hiperparâmetros dos algoritmos, que indicam o valor real daquele hiperparâmetro naquela execução.

# %% [markdown]
# ### Limpeza e Padronização dos dados:
# - Remover execuções que os targets sejam NaN;
# - Renomear a coluna 'feature preprocessing' para um formato mais intuitivo;
# - Binarizar a coluna 'feature preprocessing';
# - Binarizar as colunas categóricas (nome dos algoritmos):
# Caso a coluna possua o caractere '-' ela será uma coluna de **hiperparâmetros** e não deve ser incluída na lista; caso contrário, ela será incluída e binarizada. Isso será feito para todas as colunas exceto as 2 primeiras e últimas, que são casos especiais;
# - Preencher as colunas numéricas (colunas que representam hiperparâmetros) com -1. Esse valor será usado pois alguns hiperparâmetros podem assumir o valor 0, e usar este valor pode confundir o modelo. Além disso, nenhum hiperparâmetro assume -1;
#
# O dataset completo possui 60 colunas categóricas (nome dos algoritmos), 145 colunas numéricas (hiperparâmetros) e 4 "especiais": normalize, feature preprocessing, F1-score e Model Size.

# %%
# Execuções sem os valores dos targets não servem para treinar um modelo;
df.dropna(subset=['F1 (macro averaged by label)', 'Model Size'], inplace=True)

# Modelos lidam melhor com valores binários ao invés de NaN
df = df.rename(columns={'NO_FEATURE_PREPROCESSING': 'feature preprocessing'})
df['feature preprocessing'] = df['feature preprocessing'].apply(lambda x: 0 if x == 0 else 1)

# %%
# Lista de colunas que serão binarizadas (categóricas)
# As 2 primeiras e últimas são especiais
columns = [column for column in df.columns[2:-2] if '-' not in column]

for column in columns:
    df[column] = df[column].apply(lambda x: 1 if x == 0 else 0)

# %%
# Lista de colunas numéricas
columns_to_fill = [
    col for col in df.columns[2:-2]
    if col not in columns
]

# Preenchendo com -1 pois hiperparâmetros podem assumir valor 0 
df[columns_to_fill] = df[columns_to_fill].fillna(-1)

# %% [markdown]
# ### Verificação final e gráficos

# %%
# Para desfragmentar a memória (otimizar)
clean_df = df.copy()

# Criando a coluna "model size log" para tratar a escala de model size 
clean_df['Model Size Log'] = np.log1p(clean_df['Model Size'])

# Plotando gráficos para identificar padrões
sns.set_theme(style="whitegrid")

# Histograma do Macro F-score 
plt.figure(figsize=(10, 6))
sns.histplot(clean_df['F1 (macro averaged by label)'], kde=True, bins=30)
plt.title('Distribuição do Macro F-score', fontsize=16)
plt.xlabel('Macro F-score')
plt.ylabel('Contagem')
plt.show()

# Histograma do Tamanho do Modelo 
plt.figure(figsize=(10, 6))
sns.histplot(clean_df['Model Size Log'], kde=True, bins=30)
plt.title('Distribuição do Tamanho do Modelo', fontsize=16)
plt.xlabel('Tamanho do Modelo')
plt.ylabel('Contagem')
plt.show()

# Scatter Plot (Relação entre os Alvos)
plt.figure(figsize=(12, 8))
sns.scatterplot(data=clean_df, x='Model Size', y='F1 (macro averaged by label)', alpha=0.5)
plt.title('Relação entre Tamanho do Modelo e F1-score', fontsize=16)
plt.xlabel('Tamanho do Modelo')
plt.ylabel('Macro F-score')
plt.show()

# %%
# Última verificação
nans = clean_df.isnull().sum().sum()
print(f"total de NaNs após o processamento: {nans}")

# Salvando o df limpo em .csv 
clean_df.to_csv('../data/processed/proc_birds.csv', index=False)
# Out:
# total de NaNs após o processamento: 0

# %% [markdown]
# ### Aqui termina todo o processo de pré-processamento. Este processo foi movido para a função `src/preprocess_data()` e foi aplicado em todos os conjuntos de dados. Dessa forma, os dados que serão utilizados para treinar os modelos estão disponíveis em `data/meta/meta_processed`.

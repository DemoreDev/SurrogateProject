# %%
import pandas as pd
path1 = "./ranked_models/ranked_models_birds.csv"
path2 = "./ranked_models/ranked_models_medical.csv"
path3 = "./ranked_models/ranked_models_enron.csv"
path4 = "./ranked_models/ranked_models_scene.csv"
path5 = "./ranked_models/ranked_models_yeast.csv"
path6 = "./ranked_models/all_models.csv"
df = pd.read_csv(path1)
df.head(6)
# Out:
#                 Model_Name   R2_F1  R2_ModelSize_Log  RMSE_F1  \
# 0     xgboost_multi_output  0.9546            0.9977   0.0315
# 1  xgboost_regressor_chain  0.9546            0.9972   0.0315
# 2     lgbm_regressor_chain  0.9506            0.9974   0.0329
# 3    catboost_multi_output  0.9444            0.9973   0.0349
# 4        lgbm_multi_output  0.9439            0.9972   0.0351
# 5               mlp_native  0.9180            0.9973   0.0424
#
#    RMSE_ModelSize_Log  Disk_Size_mb  Inference_time Dataset_Source  \
# 0              0.1027       24.5571        0.002637          birds
# 1              0.1135       33.8950        0.045598          birds
# 2              0.1100       10.5283        0.023401          birds
# 3              0.1120       14.5102        0.003020          birds
# 4              0.1138        8.0488        0.011798          birds
# 5              0.1104        1.2649        0.000682          birds
#
#    Weighted_Score
# 0        0.969685
# ...

# %%
df2 = pd.read_csv(path2)
df2.head(6)
# Out:
#                 Model_Name   R2_F1  R2_ModelSize_Log  RMSE_F1  \
# 0  xgboost_regressor_chain  0.9755            0.9948   0.0340
# 1     xgboost_multi_output  0.9748            0.9949   0.0345
# 2        lgbm_multi_output  0.9731            0.9936   0.0356
# 3    catboost_multi_output  0.9712            0.9951   0.0368
# 4     lgbm_regressor_chain  0.9714            0.9935   0.0367
# 5               mlp_native  0.9429            0.9936   0.0519
#
#    RMSE_ModelSize_Log  Disk_Size_mb  Inference_time Dataset_Source  \
# 0              0.1507       22.4501        0.004476        medical
# 1              0.1498       16.5610        0.002338        medical
# 2              0.1671        7.7694        0.002508        medical
# 3              0.1461       29.9580        0.002755        medical
# 4              0.1683        5.9617        0.004151        medical
# 5              0.1668        0.6919        0.000605        medical
#
#    Weighted_Score
# 0        0.982255
# ...

# %%
df3 = pd.read_csv(path3)
df3.head(6)
# Out:
#                    Model_Name   R2_F1  R2_ModelSize_Log  RMSE_F1  \
# 0        xgboost_multi_output  0.9672            0.9928   0.0097
# 1     xgboost_regressor_chain  0.9661            0.9917   0.0098
# 2           lgbm_multi_output  0.9641            0.9927   0.0101
# 3        lgbm_regressor_chain  0.9638            0.9916   0.0101
# 4       catboost_multi_output  0.9601            0.9926   0.0107
# 5  random_forest_multi_output  0.9157            0.9798   0.0155
#
#    RMSE_ModelSize_Log  Disk_Size_mb  Inference_time Dataset_Source  \
# 0              0.1891       25.1153        0.002230          enron
# 1              0.2030       16.4276        0.004648          enron
# 2              0.1905        8.9223        0.002254          enron
# 3              0.2046       10.1653        0.003856          enron
# 4              0.1912       15.1407        0.002762          enron
# 5              0.3169     8773.0649        0.145105          enron
#
#    Weighted_Score
# ...

# %%
df4 = pd.read_csv(path4)
df4.head(6)
# Out:
#                 Model_Name   R2_F1  R2_ModelSize_Log  RMSE_F1  \
# 0     xgboost_multi_output  0.9627            0.9960   0.0277
# 1  xgboost_regressor_chain  0.9608            0.9948   0.0284
# 2    catboost_multi_output  0.9600            0.9961   0.0287
# 3     lgbm_regressor_chain  0.9578            0.9951   0.0295
# 4        lgbm_multi_output  0.9536            0.9957   0.0309
# 5               mlp_native  0.8923            0.9937   0.0470
#
#    RMSE_ModelSize_Log  Disk_Size_mb  Inference_time Dataset_Source  \
# 0              0.1441       25.1796        0.032402          scene
# 1              0.1630       28.7287        0.098400          scene
# 2              0.1421       23.9003        0.003136          scene
# 3              0.1583       10.9199        0.031786          scene
# 4              0.1492        6.3988        0.012395          scene
# 5              0.1808        0.9239        0.000501          scene
#
#    Weighted_Score
# 0        0.974355
# ...

# %%
df5 = pd.read_csv(path5)
df5.head(6)
# Out:
#                    Model_Name   R2_F1  R2_ModelSize_Log  RMSE_F1  \
# 0     xgboost_regressor_chain  0.9610            0.9967   0.0142
# 1        xgboost_multi_output  0.9572            0.9971   0.0149
# 2       catboost_multi_output  0.9569            0.9970   0.0149
# 3        lgbm_regressor_chain  0.9517            0.9963   0.0158
# 4           lgbm_multi_output  0.9494            0.9964   0.0162
# 5  random_forest_multi_output  0.8745            0.9823   0.0255
#
#    RMSE_ModelSize_Log  Disk_Size_mb  Inference_time Dataset_Source  \
# 0              0.1321       31.3966        0.009125          yeast
# 1              0.1248       17.4837        0.040582          yeast
# 2              0.1259       30.8398        0.010583          yeast
# 3              0.1409        9.1377        0.003928          yeast
# 4              0.1379        9.0190        0.012198          yeast
# 5              0.3067     1615.7167        0.027074          yeast
#
#    Weighted_Score
# ...

# %%
df6 = pd.read_csv(path6)
df6
# Out:
#    Dataset_Source                     Model_Name   R2_F1  R2_ModelSize_Log  \
# 0           birds           xgboost_multi_output  0.9546            0.9977
# 1           birds        xgboost_regressor_chain  0.9546            0.9972
# 2           birds           lgbm_regressor_chain  0.9506            0.9974
# 3           birds          catboost_multi_output  0.9444            0.9973
# 4           birds              lgbm_multi_output  0.9439            0.9972
# 5           birds                     mlp_native  0.9180            0.9973
# 6           birds     random_forest_multi_output  0.9161            0.9880
# 7           birds  random_forest_regressor_chain  0.9164            0.9872
# 8           birds           random_forest_native  0.8644            0.9867
# 9           birds                     knn_native  0.8156            0.9641
# 10          birds             ridge_multi_output  0.7511            0.9431
# ...
